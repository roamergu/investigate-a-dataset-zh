# %% [markdown]
# # 项目：TMDB数据分析
#
# ## 目录
# <ul>
# <li><a href="#intro">简介</a></li>
# <li><a href="#wrangling">数据整理</a></li>
# <li><a href="#eda">探索性数据分析</a></li>
# <li><a href="#conclusions">结论</a></li>
# </ul>
#
# <a id='intro'></a>
# ## 简介
#
# > **提示**：在报告的这一部分，你需要首先对已选择进行分析的数据集进行简要的介绍。在这一部分末尾，对你计划在报告过程中探索的问题进行描述。你需要建立至少包含一个因变量和三个自变量的分析报告。如果你不确定要问什么问题，请务必先熟悉数据集、数据集变量以及数据集上下文，以便确定要探索的问题。
#
# TMDb电影数据集包括1万条电影信息，信息来源为“电影数据库”（TMDb，The Movie Database），包括电影基本信息、用户评分和票房等信息。其中“演职人员 (cast)”、“电影类别 (genres)”等数据列包含由竖线字符（|）分隔的多个数值。 在这个项目中，我们将探索电影投资额与哪些市场表现相关，电影收益与哪些因素相关。

# %%
# 用这个框对你计划使用的所有数据包进行设置
#   导入语句。
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# 务必包含一个‘magic word’（带有“%”的***），以便将你的视图
#   与 notebook 保持一致。关于更多信息，请访问该网页：
#   http://ipython.readthedocs.io/en/stable/interactive/magics.html

# %% [markdown]
# <a id='wrangling'></a>
# ## 数据整理
#
# ### 常规属性观察

# %%
# 加载数据并打印几行。进行这几项操作，来检查数据
#   类型，以及是否有缺失数据或错误数据的情况。
df_tmdb = pd.read_csv('tmdb-movies.csv')
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %%
df_tmdb.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df_tmdb.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %% [markdown]
# ###  进一步整理
# 观察到投资列与收益列统计学意义为0，考虑到本研究会探索利益的影响因素，将投资值为0与收益值为0的数据行依次删除。

# %%
df_tmdb = df_tmdb[df_tmdb['revenue']>0]
df_tmdb = df_tmdb[df_tmdb['budget']>0]
df_tmdb.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    3855.000000  3855.000000  3.855000e+03  3.855000e+03  3855.000000
# mean    39888.783398     1.191400  3.720183e+07  1.076589e+08   109.215824
# std     67213.815955     1.475002  4.220291e+07  1.765248e+08    19.922166
# min         5.000000     0.001117  1.000000e+00  2.000000e+00    15.000000
# 25%      6074.000000     0.462448  1.000000e+07  1.357645e+07    95.000000
# 50%     11322.000000     0.797298  2.400000e+07  4.479322e+07   106.000000
# 75%     38577.000000     1.368245  5.000000e+07  1.241530e+08   119.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   338.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  3855.000000    3855.00000   3855.000000  3.855000e+03  3.855000e+03
# mean    527.611933       6.16786   2001.263294  4.423630e+07  1.370294e+08
# ...

# %%
df_tmdb.shape
# Out:
# (3855, 21)

# %% [markdown]
# 清理以后，统计学意义为0的数据消失了。

# %%
 df_tmdb.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#选择关注的数据集
df_tmdb[['popularity','budget','revenue','runtime','vote_count','vote_average','release_year']].describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  3855.000000  3.855000e+03  3.855000e+03  3855.000000  3855.000000
# mean      1.191400  3.720183e+07  1.076589e+08   109.215824   527.611933
# std       1.475002  4.220291e+07  1.765248e+08    19.922166   879.868374
# min       0.001117  1.000000e+00  2.000000e+00    15.000000    10.000000
# 25%       0.462448  1.000000e+07  1.357645e+07    95.000000    71.000000
# 50%       0.797298  2.400000e+07  4.479322e+07   106.000000   204.000000
# 75%       1.368245  5.000000e+07  1.241530e+08   119.000000   580.000000
# max      32.985763  4.250000e+08  2.781506e+09   338.000000  9767.000000
#
#        vote_average  release_year
# count    3855.00000   3855.000000
# mean        6.16786   2001.263294
# std         0.79504     11.281989
# min         2.20000   1960.000000
# 25%         5.70000   1995.000000
# 50%         6.20000   2004.000000
# 75%         6.70000   2010.000000
# ...

# %% [markdown]
# # <a id='eda'></a>
# ## 探索性数据分析
#
#
# ### 研究：电影投资因素

# %%
#观察电影投资的分布图
df_tmdb['budget'].plot(kind = 'hist',figsize = (8,8));

# %% [markdown]
# 我们发现电影的投资数额表现非常集中。下面我们观察一下投资收益之间的关系

# %%
df_tmdb.plot(x='budget',y='revenue',kind = 'scatter',figsize = (8,8));

# %% [markdown]
# 投资额在1e之前，与收益的正相关性比较明显，但并非完全如此。越过一个界限以后，则关联性不大。

# %%
df_tmdb.plot(x='release_year',y='budget',kind = 'scatter',figsize = (8,8));

# %%
df_tmdb.plot(x='release_year',y='revenue',kind = 'scatter',figsize = (8,8));

# %% [markdown]
# 两幅图对比下来发现，投资额与收益额都随时代发展而增长，但总体来说，投资收益比是下降的。可能拍电影越来越不挣钱了。

# %%
df_tmdb.plot(x='popularity',y='budget',kind = 'scatter',figsize = (8,8));

# %% [markdown]
# 电影的普及程度与投资表现出一定的相关性.

# %% [markdown]
# <a id='conclusions'></a>
# ## 结论
# 首先，本次数据分析存在很大局限性，为了考察目标因素，我对数据集进行了清洗，导致样本不足。
# 在数据样本不足的前提下，我们可以得出如下结论：
# 1.随着时代的发展，电影的成本与收益绝对值都在增长，但收益增长的要慢一点。
# 2.对同一时代而言，电影并非投资越高，收益越高，二者存在一定相关性，但因果性不明显。
# 3.对整个电影市场而言，难以预测收益。

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 4294967295
